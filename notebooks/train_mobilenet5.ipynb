# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import pickle

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import AdamW

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay


import wandb
from wandb.integration.keras import WandbMetricsLogger, WandbModelCheckpoint

import warnings
warnings.filterwarnings("ignore")

# %%
os.environ["WANDB_API_KEY"] = "cd71d6f2249981dffae87be7baa57f08fe64c95e"
os.environ["WANDB_MODE"] = "online"
wandb.login()
# Out:
# wandb: Currently logged in as: omarhariri (omarhariri-syrian-private-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
run = wandb.init(
    project="driver-drowsiness",
    name="mobilenetv2_transfer5",
    config={
        "img_size": 224,
        "batch_size": 32,
        "epochs": 50,
        "optimizer": "AdamW",
        "architecture": "MobileNetV2",
        "learning_rate": 1e-4,
        "weight_decay":1e-3,
        "loss": "binary_crossentropy",
    }
)

config = wandb.config
# Out:
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>d:\SPU\Lectures\y5_s1\Practical_Deep_Learning\project\notebooks\wandb\run-20260101_193343-ja4jh6ij</code>
# Syncing run <strong><a href='https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness/runs/ja4jh6ij' target="_blank">mobilenetv2_transfer5</a></strong> to <a href='https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness' target="_blank">https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness</a>
#  View run at <a href='https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness/runs/ja4jh6ij' target="_blank">https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness/runs/ja4jh6ij</a>

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=10,
    zoom_range=0.1,
    brightness_range=(0.8, 1.2),
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    "../data/train",
    target_size=(config.img_size, config.img_size),
    batch_size=config.batch_size,
    class_mode="binary",
    color_mode="rgb",
    shuffle=True
)

val_generator = val_test_datagen.flow_from_directory(
    "../data/val",
    target_size=(config.img_size, config.img_size),
    batch_size=config.batch_size,
    class_mode="binary",
    color_mode="rgb",
    shuffle=False
)

test_generator = val_test_datagen.flow_from_directory(
    "../data/test",
    target_size=(config.img_size, config.img_size),
    batch_size=config.batch_size,
    class_mode="binary",
    color_mode="rgb",
    shuffle=False
)
# Out:
# Found 1890 images belonging to 2 classes.
# Found 405 images belonging to 2 classes.
# Found 407 images belonging to 2 classes.

# %%
x_batch, y_batch = next(train_generator)

fig, axes = plt.subplots(1, 5, figsize=(12, 3))

for i in range(5):
    img = x_batch[i]

    # Reverse preprocess_input FOR VISUALIZATION ONLY
    img_vis = (img + 1.0) / 2.0        # [-1,1] -> [0,1]
    img_vis = np.clip(img_vis, 0, 1)

    axes[i].imshow(img_vis)
    axes[i].set_title(f"Label: {int(y_batch[i])}")
    axes[i].axis("off")

plt.show()

# %%
print(train_generator.class_indices)
# Out:
# {'normal': 0, 'yawn': 1}

# %%
base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(config.img_size, config.img_size, 3)
)

base_model.trainable = False

# %%
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
])


model.compile(
    optimizer=AdamW(learning_rate=config.learning_rate, weight_decay= config.weight_decay),
    loss=tf.keras.losses.BinaryCrossentropy(label_smoothing=0.1),
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,081 (9.24 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=4,
    restore_best_weights=True,
)

checkpoint = WandbModelCheckpoint(
    filepath="../models/mobilenet5/best.keras",
    monitor="val_loss",
    save_best_only=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=2,
    min_lr=1e-6,
)

callbacks = [
    early_stop,
    checkpoint,
    reduce_lr,
    WandbMetricsLogger()
]
# Out:
# wandb: WARNING When using `save_best_only`, ensure that the `filepath` argument contains formatting placeholders like `{epoch:02d}` or `{batch:02d}`. This ensures correct interpretation of the logged artifacts.

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=config.epochs,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.6305 - loss: 0.7014 - val_accuracy: 0.7926 - val_loss: 0.5253 - learning_rate: 1.0000e-04
# Epoch 2/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.7553 - loss: 0.5563 - val_accuracy: 0.8296 - val_loss: 0.4744 - learning_rate: 1.0000e-04
# Epoch 3/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.8148 - loss: 0.4789 - val_accuracy: 0.8321 - val_loss: 0.4535 - learning_rate: 1.0000e-04
# Epoch 4/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.8551 - loss: 0.4523 - val_accuracy: 0.8642 - val_loss: 0.4348 - learning_rate: 1.0000e-04
# Epoch 5/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.8477 - loss: 0.4464 - val_accuracy: 0.8494 - val_loss: 0.4377 - learning_rate: 1.0000e-04
# Epoch 6/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.8645 - loss: 0.4350 - val_accuracy: 0.8840 - val_loss: 0.4109 - learning_rate: 1.0000e-04
# Epoch 7/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.8777 - loss: 0.4172 - val_accuracy: 0.8741 - val_loss: 0.4067 - learning_rate: 1.0000e-04
# Epoch 8/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.8604 - loss: 0.4338 - val_accuracy: 0.8840 - val_loss: 0.4000 - learning_rate: 1.0000e-04
# Epoch 9/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.8578 - loss: 0.4333 - val_accuracy: 0.8864 - val_loss: 0.3933 - learning_rate: 1.0000e-04
# Epoch 10/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.8739 - loss: 0.3995 - val_accuracy: 0.8914 - val_loss: 0.3914 - learning_rate: 1.0000e-04
# Epoch 11/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.8848 - loss: 0.3990 - val_accuracy: 0.8938 - val_loss: 0.3883 - learning_rate: 1.0000e-04
# Epoch 12/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.8853 - loss: 0.4100 - val_accuracy: 0.8914 - val_loss: 0.3828 - learning_rate: 1.0000e-04
# Epoch 13/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.8866 - loss: 0.3994 - val_accuracy: 0.8938 - val_loss: 0.3802 - learning_rate: 1.0000e-04
# Epoch 14/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.8992 - loss: 0.4023 - val_accuracy: 0.8938 - val_loss: 0.3876 - learning_rate: 1.0000e-04
# Epoch 15/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.8939 - loss: 0.3977 - val_accuracy: 0.8889 - val_loss: 0.3787 - learning_rate: 1.0000e-04
# Epoch 16/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.9052 - loss: 0.3825 - val_accuracy: 0.8938 - val_loss: 0.3759 - learning_rate: 1.0000e-04
# Epoch 17/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.9018 - loss: 0.3809 - val_accuracy: 0.8963 - val_loss: 0.3819 - learning_rate: 1.0000e-04
# Epoch 18/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.8985 - loss: 0.3776 - val_accuracy: 0.8963 - val_loss: 0.3775 - learning_rate: 1.0000e-04
# Epoch 19/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.8935 - loss: 0.3827 - val_accuracy: 0.8963 - val_loss: 0.3738 - learning_rate: 3.0000e-05
# Epoch 20/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 90s 2s/step - accuracy: 0.8937 - loss: 0.3866 - val_accuracy: 0.8988 - val_loss: 0.3740 - learning_rate: 3.0000e-05
# Epoch 21/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9093 - loss: 0.3670 - val_accuracy: 0.8963 - val_loss: 0.3731 - learning_rate: 3.0000e-05
# Epoch 22/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.9085 - loss: 0.3823 - val_accuracy: 0.8963 - val_loss: 0.3743 - learning_rate: 3.0000e-05
# Epoch 23/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 92s 2s/step - accuracy: 0.9119 - loss: 0.3720 - val_accuracy: 0.8963 - val_loss: 0.3738 - learning_rate: 3.0000e-05
# Epoch 24/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step - accuracy: 0.9102 - loss: 0.3694 - val_accuracy: 0.8963 - val_loss: 0.3718 - learning_rate: 9.0000e-06
# Epoch 25/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.8861 - loss: 0.3851 - val_accuracy: 0.8963 - val_loss: 0.3702 - learning_rate: 9.0000e-06
# Epoch 26/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.9196 - loss: 0.3551 - val_accuracy: 0.8963 - val_loss: 0.3727 - learning_rate: 9.0000e-06
# Epoch 27/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step - accuracy: 0.9090 - loss: 0.3628 - val_accuracy: 0.8963 - val_loss: 0.3715 - learning_rate: 9.0000e-06
# Epoch 28/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.9071 - loss: 0.3768 - val_accuracy: 0.8963 - val_loss: 0.3718 - learning_rate: 2.7000e-06
# Epoch 29/50
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.8966 - loss: 0.3892 - val_accuracy: 0.8963 - val_loss: 0.3711 - learning_rate: 2.7000e-06

# %%
y_pred_probs = model.predict(test_generator, verbose=1)
y_pred = (y_pred_probs > 0.3).astype(int).ravel()
y_true = test_generator.classes
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
)

acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred)
rec = recall_score(y_true, y_pred)   # THIS IS CRITICAL
f1 = f1_score(y_true, y_pred)
print(f"accuracy_score:{acc}\nprecision_score:{prec}\nrecall_score:{rec}\nf1_score:{f1}")
# Out:
# accuracy_score:0.8746928746928747
# precision_score:0.7565217391304347
# recall_score:0.7909090909090909
# f1_score:0.7733333333333333

# %%
wandb.log({
    "test_accuracy": acc,
    "test_precision": prec,
    "test_recall": rec,
    "test_f1": f1
})

# %%
class_names = list(test_generator.class_indices.keys())
report = classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4,
)

print("\nClassification Report:\n")
print(report)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       normal     0.9212    0.9057    0.9134       297
#         yawn     0.7565    0.7909    0.7733       110
#
#     accuracy                         0.8747       407
#    macro avg     0.8389    0.8483    0.8434       407
# weighted avg     0.8767    0.8747    0.8756       407

# %%
# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
cmd = ConfusionMatrixDisplay(cm, display_labels=['awake','sleepy'])
cmd.plot(cmap=plt.cm.Blues, values_format='d', ax=plt.gca())
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
with open("../models/mobilenet5/history.pkl", "wb") as f:
    pickle.dump(history.history, f)

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▄▅▆▆▇▇▇▇▇▇▇▇█▇██████████████</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>epoch/learning_rate</td><td>█████████████████▃▃▃▃▃▂▂▂▂▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▃▄▆▅▇▆▇▇█████▇██████████████</td></tr><tr><td>epoch/val_loss</td><td>█▆▅▄▄▃▃▂▂▂▂▂▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.90899</td></tr><tr><td>epoch/epoch</td><td>28</td></tr><tr><td>epoch/learning_rate</td><td>0.0</td></tr><tr><td>epoch/loss</td><td>0.3675</td></tr><tr><td>epoch/val_accuracy</td><td>0.8963</td></tr><tr><td>epoch/val_loss</td><td>0.3711</td></tr><tr><td>test_accuracy</td><td>0.87469</td></tr><tr><td>test_f1</td><td>0.77333</td></tr><tr><td>test_precision</td><td>0.75652</td></tr><tr><td>test_recall</td><td>0.79091</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">mobilenetv2_transfer5</strong> at: <a href='https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness/runs/ja4jh6ij' target="_blank">https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness/runs/ja4jh6ij</a><br> View project at: <a href='https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness' target="_blank">https://wandb.ai/omarhariri-syrian-private-university/driver-drowsiness</a><br>Synced 5 W&B file(s), 0 media file(s), 36 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260101_193343-ja4jh6ij\logs</code>
